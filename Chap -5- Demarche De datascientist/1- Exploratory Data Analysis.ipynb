# %% [markdown]
# <a
# href="https://colab.research.google.com/github/adilo231/Python-for-machine-learning/blob/main/Chap -5- Demarche De datascientist/1- Exploratory Data Analysis.ipynb"
# target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_row', 111)
pd.set_option('display.max_column', 111)

# %%
data = pd.read_excel('Datasets/dataset.xlsx')

# %%
data.head()
# Out:
#         Patient ID  Patient age quantile SARS-Cov-2 exam result  \
# 0  44477f75e8169d2                    13               negative
# 1  126e9dd13932f68                    17               negative
# 2  a46b4402a0e5696                     8               negative
# 3  f7d619a94f97c45                     5               negative
# 4  d9e41465789c2b5                    15               negative
#
#    Patient addmited to regular ward (1=yes, 0=no)  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# ...

# %% [markdown]
# # 1. Exploratory Data Analysis
#
# ## Objectif :
# - Comprendre du mieux possible nos données
# - Développer une premiere stratégie de modélisation
#
# ## Checklist de base
# #### Analyse de Forme :
# - **variable target** : -----
# - **lignes et colonnes** : -----
# - **types de variables** : -----
# - **Analyse des valeurs manquantes** : -----
#
#
# #### Analyse de Fond :
# - **Visualisation de la target** :
#    - **
#    - **
#    - **
#
#
#
# - **Signification des variables** :
#    - **
#    - **
#    - **
#
#
#
# - **Relation Variables / Target** :
#    - **
#    - **
#    - **
#
#
#
# ## Analyse plus détaillée
#
# - **Relation Variables / Variables** :
#    - **
#    - **
#    - **
#
#
# - **NaN analyse** :
#    - **
#    - **
#    - **
#
# ### hypotheses nulle (H0):
#    - **
#    - **
#    - **

# %% [markdown]
# ### Analyse de la forme des données

# %%
df = data.copy()

# %%
df.shape
# Out:
# (5644, 111)

# %% [markdown]
# ## Analyse du Fond
# ### Visulation initiale - Elimination des colonnes inutiles

# %% [markdown]
# ### Examen de la colonne target

# %% [markdown]
# ### histogrames des variables continues

# %% [markdown]
# ### Variables Qualitatives

# %% [markdown]
# ## Relation Target / Variables

# %% [markdown]
# ## Analyse plus Avancée
